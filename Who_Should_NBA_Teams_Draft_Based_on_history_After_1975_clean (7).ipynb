# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df1 = pd.read_excel(r"C:\Users\sbrooks003\OneDrive - defiance.edu\seasons(updated).xlsx",sheet_name='Sheet1')
df1
# Out:
#        Year                Player Pos  Age   Tm   G    GS        MPG    MP  \
# 0      1975       Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450
# 1      1975  Kareem Abdul-Jabbar*   C   27  MIL  65   NaN  42.261538  2747
# 2      1975             Don Adams  SF   27  DET  51   NaN  26.980392  1376
# 3      1975          Rick Adelman  PG   28  TOT  58   NaN  18.517241  1074
# 4      1975          Lucius Allen  PG   27  TOT  66   NaN  35.651515  2353
# ...     ...                   ...  ..  ...  ...  ..   ...        ...   ...
# 20538  2017           Cody Zeller  PF   24  CHO  62  58.0  27.822581  1725
# 20539  2017          Tyler Zeller   C   27  BOS  51   5.0  10.294118   525
# 20540  2017     Stephen Zimmerman   C   20  ORL  19   0.0   5.684211   108
# 20541  2017           Paul Zipser  SF   22  CHI  44  18.0  19.159091   843
# 20542  2017           Ivica Zubac   C   19  LAL  38  11.0  16.026316   609
#
#         PER  ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK   TOV   PF  \
# 0      17.1  ...  1.292308   84  0.569231   37  1.138462   74   NaN  128
# 1      26.4  ...  4.061538  264  1.000000   65  3.261538  212   NaN  205
# 2       8.4  ...  1.470588   75  1.352941   69  0.392157   20   NaN  179
# 3      11.1  ...  1.931034  112  1.206897   70  0.137931    8   NaN  101
# 4      17.5  ...  5.636364  372  2.060606  136  0.439394   29   NaN  217
# ...     ...  ...       ...  ...       ...  ...       ...  ...   ...  ...
# 20538  16.7  ...  1.596774   99  1.000000   62  0.935484   58  65.0  189
# 20539  13.0  ...  0.823529   42  0.137255    7  0.411765   21  20.0   61
# 20540   7.3  ...       NaN    4       NaN    2  0.263158    5   3.0   17
# 20541   6.9  ...  0.818182   36  0.340909   15  0.363636   16  40.0   78
# 20542  17.0  ...  0.789474   30  0.368421   14  0.868421   33  30.0   66
#
#              PPG   PTS
# 0       9.676923   629
# 1      29.984615  1949
# 2       5.862745   299
# 3       5.500000   319
# 4      19.090909  1260
# ...          ...   ...
# 20538  10.306452   639
# 20539   3.490196   178
# 20540        NaN    23
# 20541   5.454545   240
# 20542   7.473684   284
#
# [20543 rows x 42 columns]

# %%
df1_1 = df1.set_index('Year')
df1_1
# Out:
#                     Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# Year
# 1975       Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 1975  Kareem Abdul-Jabbar*   C   27  MIL  65   NaN  42.261538  2747  26.4
# 1975             Don Adams  SF   27  DET  51   NaN  26.980392  1376   8.4
# 1975          Rick Adelman  PG   28  TOT  58   NaN  18.517241  1074  11.1
# 1975          Lucius Allen  PG   27  TOT  66   NaN  35.651515  2353  17.5
# ...                    ...  ..  ...  ...  ..   ...        ...   ...   ...
# 2017           Cody Zeller  PF   24  CHO  62  58.0  27.822581  1725  16.7
# 2017          Tyler Zeller   C   27  BOS  51   5.0  10.294118   525  13.0
# 2017     Stephen Zimmerman   C   20  ORL  19   0.0   5.684211   108   7.3
# 2017           Paul Zipser  SF   22  CHI  44  18.0  19.159091   843   6.9
# 2017           Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#         TS%  ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK   TOV   PF  \
# Year         ...
# 1975  0.501  ...  1.292308   84  0.569231   37  1.138462   74   NaN  128
# 1975  0.550  ...  4.061538  264  1.000000   65  3.261538  212   NaN  205
# 1975  0.428  ...  1.470588   75  1.352941   69  0.392157   20   NaN  179
# 1975  0.474  ...  1.931034  112  1.206897   70  0.137931    8   NaN  101
# 1975  0.483  ...  5.636364  372  2.060606  136  0.439394   29   NaN  217
# ...     ...  ...       ...  ...       ...  ...       ...  ...   ...  ...
# 2017  0.604  ...  1.596774   99  1.000000   62  0.935484   58  65.0  189
# 2017  0.508  ...  0.823529   42  0.137255    7  0.411765   21  20.0   61
# 2017  0.346  ...       NaN    4       NaN    2  0.263158    5   3.0   17
# 2017  0.503  ...  0.818182   36  0.340909   15  0.363636   16  40.0   78
# 2017  0.547  ...  0.789474   30  0.368421   14  0.868421   33  30.0   66
#
#             PPG   PTS
# Year
# 1975   9.676923   629
# 1975  29.984615  1949
# 1975   5.862745   299
# 1975   5.500000   319
# 1975  19.090909  1260
# ...         ...   ...
# 2017  10.306452   639
# 2017   3.490196   178
# 2017        NaN    23
# 2017   5.454545   240
# 2017   7.473684   284
#
# [20543 rows x 41 columns]

# %%
df1 = df1.sort_values(by = 'Year', ascending = True).head(25000)
df1
# Out:
#        Year           Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975  Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 170    1975      Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975    Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 172    1975   Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975        Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# ...     ...              ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20146  2017     Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017     Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20148  2017     Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
# 20150  2017   Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
# 20542  2017      Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK    TOV   PF  \
# 0      ...  1.292308   84  0.569231   37  1.138462   74    NaN  128
# 170    ...  5.101266  403  1.405063  111  0.088608    7    NaN  288
# 171    ...       NaN    4       NaN    3  0.083333    1    NaN    9
# 172    ...       NaN   16       NaN   23  0.000000    0    NaN   51
# 173    ...  1.195122   49  0.390244   16  0.048780    2    NaN   27
# ...    ...       ...  ...       ...  ...       ...  ...    ...  ...
# 20146  ...       NaN    0       NaN    0  2.000000    4    3.0    5
# 20147  ...  0.589744   46  0.423077   33  0.961538   75   41.0  144
# 20148  ...  1.904762  120  0.746032   47  0.126984    8   44.0   93
# 20150  ...  7.013158  533  2.026316  154  1.394737  106  184.0  217
# 20542  ...  0.789474   30  0.368421   14  0.868421   33   30.0   66
#
#              PPG   PTS
# 0       9.676923   629
# 170    14.392405  1137
# 171          NaN    48
# 172          NaN   159
# 173     3.024390   124
# ...          ...   ...
# 20146        NaN    16
# 20147   5.397436   421
# 20148   5.873016   370
# 20150  10.210526   776
# 20542   7.473684   284
#
# [20543 rows x 42 columns]

# %%
df1 = df1[df1['Year'] >= 1975]
df1
# Out:
#        Year           Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975  Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 170    1975      Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975    Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 172    1975   Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975        Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# ...     ...              ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20146  2017     Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017     Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20148  2017     Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
# 20150  2017   Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
# 20542  2017      Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK    TOV   PF  \
# 0      ...  1.292308   84  0.569231   37  1.138462   74    NaN  128
# 170    ...  5.101266  403  1.405063  111  0.088608    7    NaN  288
# 171    ...       NaN    4       NaN    3  0.083333    1    NaN    9
# 172    ...       NaN   16       NaN   23  0.000000    0    NaN   51
# 173    ...  1.195122   49  0.390244   16  0.048780    2    NaN   27
# ...    ...       ...  ...       ...  ...       ...  ...    ...  ...
# 20146  ...       NaN    0       NaN    0  2.000000    4    3.0    5
# 20147  ...  0.589744   46  0.423077   33  0.961538   75   41.0  144
# 20148  ...  1.904762  120  0.746032   47  0.126984    8   44.0   93
# 20150  ...  7.013158  533  2.026316  154  1.394737  106  184.0  217
# 20542  ...  0.789474   30  0.368421   14  0.868421   33   30.0   66
#
#              PPG   PTS
# 0       9.676923   629
# 170    14.392405  1137
# 171          NaN    48
# 172          NaN   159
# 173     3.024390   124
# ...          ...   ...
# 20146        NaN    16
# 20147   5.397436   421
# 20148   5.873016   370
# 20150  10.210526   776
# 20542   7.473684   284
#
# [20543 rows x 42 columns]

# %%
guards = ['PG','SG']

df1[df1['Pos'].isin(guards)]
# Out:
#        Year          Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 170    1975     Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975   Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 176    1975    Geoff Petrie  PG   26  POR  80   NaN  38.862500  3109  14.1
# 180    1975    Kevin Porter  PG   24  WSB  81   NaN  31.962963  2589  16.0
# 181    1975       Jim Price  PG   25  TOT  50   NaN  37.400000  1870  16.1
# ...     ...             ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20139  2017  Archie Goodwin  SG   22  NOP   3   0.0  10.000000    30  19.7
# 20140  2017  Archie Goodwin  SG   22  BRK  12   0.0  15.333333   184  18.6
# 20142  2017     Eric Gordon  SG   28  HOU  75  15.0  30.973333  2323  13.1
# 20144  2017  Treveon Graham  SG   23  CHO  27   1.0   7.000000   189  10.6
# 20148  2017    Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
#
#        ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK    TOV   PF  \
# 170    ...  5.101266  403  1.405063  111  0.088608    7    NaN  288
# 171    ...       NaN    4       NaN    3  0.083333    1    NaN    9
# 176    ...  5.300000  424  1.012500   81  0.162500   13    NaN  215
# 180    ...  8.024691  650  1.876543  152  0.135802   11    NaN  320
# 181    ...  5.720000  286  2.220000  111  0.480000   24    NaN  182
# ...    ...       ...  ...       ...  ...       ...  ...    ...  ...
# 20139  ...       NaN    1       NaN    0  0.333333    1    0.0    1
# 20140  ...       NaN   23       NaN    4  0.333333    4   14.0    7
# 20142  ...  2.506667  188  0.640000   48  0.533333   40  121.0  150
# 20144  ...  0.222222    6  0.222222    6  0.037037    1    3.0   18
# 20148  ...  1.904762  120  0.746032   47  0.126984    8   44.0   93
#
#              PPG   PTS
# 170    14.392405  1137
# 171          NaN    48
# 176    18.312500  1465
# 180    11.641975   943
# 181    16.060000   803
# ...          ...   ...
# 20139        NaN    15
# 20140        NaN    95
# 20142  16.226667  1217
# 20144   2.111111    57
# 20148   5.873016   370
#
# [8077 rows x 42 columns]

# %%
forwards = ['SF', 'PF']

df1[df1['Pos'].isin(forwards)]
# Out:
#        Year          Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 172    1975  Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975       Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# 175    1975    Curtis Perry  PF   26  PHO  79   NaN  34.025316  2688  17.1
# 177    1975   Howard Porter  SF   26  TOT  58   NaN  20.051724  1163  13.4
# 178    1975   Howard Porter  SF   26  NYK  17   NaN   7.823529   133   8.4
# ...     ...             ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20141  2017    Aaron Gordon  SF   21  ORL  80  72.0  28.725000  2298  14.4
# 20145  2017    Jerami Grant  SF   22  TOT  80   4.0  19.137500  1531  10.1
# 20146  2017    Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017    Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20150  2017  Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
#
#        ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK    TOV   PF  \
# 172    ...       NaN   16       NaN   23  0.000000    0    NaN   51
# 173    ...  1.195122   49  0.390244   16  0.048780    2    NaN   27
# 175    ...  2.354430  186  1.367089  108  0.987342   78    NaN  288
# 177    ...  0.327586   19  0.396552   23  0.448276   26    NaN   93
# 178    ...       NaN    2       NaN    3  0.058824    1    NaN   17
# ...    ...       ...  ...       ...  ...       ...  ...    ...  ...
# 20141  ...  1.875000  150  0.800000   64  0.500000   40   89.0  172
# 20145  ...  0.575000   46  0.412500   33  0.987500   79   44.0  149
# 20146  ...       NaN    0       NaN    0  2.000000    4    3.0    5
# 20147  ...  0.589744   46  0.423077   33  0.961538   75   41.0  144
# 20150  ...  7.013158  533  2.026316  154  1.394737  106  184.0  217
#
#              PPG   PTS
# 172          NaN   159
# 173     3.024390   124
# 175    13.392405  1058
# 177     8.068966   468
# 178          NaN    33
# ...          ...   ...
# 20141  12.737500  1019
# 20145   5.462500   437
# 20146        NaN    16
# 20147   5.397436   421
# 20150  10.210526   776
#
# [8191 rows x 42 columns]

# %%
center = ['C']

df1[df1['Pos'].isin(center)]
# Out:
#        Year            Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975   Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 174    1975   Steve Patterson   C   26  CLE  81   NaN  15.666667  1269  11.3
# 185    1975      Clifford Ray   C   26  GSW  82   NaN  30.719512  2519  15.0
# 187    1975         Tom Riker   C   24  NYK  51   NaN   9.470588   483   9.4
# 191    1975     Rick Roberson   C   27  NOJ  16   NaN  21.187500   339  13.1
# ...     ...               ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20161  2017  Montrezl Harrell   C   23  HOU  58  14.0  18.344828  1064  19.2
# 20169  2017     Udonis Haslem   C   36  MIA  17   0.0   7.647059   130   8.4
# 20137  2017       Rudy Gobert   C   24  UTA  81  81.0  33.876543  2744  23.3
# 20143  2017     Marcin Gortat   C   32  WAS  82  82.0  31.170732  2556  15.5
# 20542  2017       Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...       ASG  AST   STL/Dis  STL   BLK/Dis  BLK    TOV   PF  \
# 0      ...  1.292308   84  0.569231   37  1.138462   74    NaN  128
# 174    ...  1.148148   93  0.259259   21  0.246914   20    NaN  128
# 185    ...  2.170732  178  1.158537   95  1.414634  116    NaN  305
# 187    ...  0.372549   19  0.294118   15  0.098039    5    NaN   64
# 191    ...       NaN   23       NaN    7  0.500000    8    NaN   49
# ...    ...       ...  ...       ...  ...       ...  ...    ...  ...
# 20161  ...  1.103448   64  0.344828   20  0.724138   42   44.0  126
# 20169  ...       NaN    6       NaN    5  0.058824    1    8.0   22
# 20137  ...  1.197531   97  0.604938   49  2.641975  214  148.0  246
# 20143  ...  1.475610  121  0.487805   40  0.792683   65  118.0  213
# 20542  ...  0.789474   30  0.368421   14  0.868421   33   30.0   66
#
#              PPG   PTS
# 0       9.676923   629
# 174     4.567901   370
# 185     9.378049   769
# 187     2.980392   152
# 191          NaN   119
# ...          ...   ...
# 20161   9.086207   527
# 20169        NaN    31
# 20137  14.037037  1137
# 20143  10.768293   883
# 20542   7.473684   284
#
# [4068 rows x 42 columns]

# %%
df1 = df1.filter(items = ['Player','Age','PPG', 'ASG', 'RBG','STL/Dis','BLK/Dis','FG/Dis','3Pper','2p/Dis','FT/Dis','Pos'])
df1
# Out:
#                 Player  Age        PPG       ASG       RBG   STL/Dis  \
# 0      Zaid Abdul-Aziz   28   9.676923  1.292308  7.507692  0.569231
# 170        Mike Newlin   26  14.392405  5.101266  3.291139  1.405063
# 171      Connie Norman   21        NaN       NaN       NaN       NaN
# 172     Willie Norwood   27        NaN       NaN       NaN       NaN
# 173          Jim Owens   24   3.024390  1.195122  1.048780  0.390244
# ...                ...  ...        ...       ...       ...       ...
# 20146     Jerami Grant   22        NaN       NaN       NaN       NaN
# 20147     Jerami Grant   22   5.397436  0.589744  2.551282  0.423077
# 20148     Jerian Grant   24   5.873016  1.904762  1.761905  0.746032
# 20150   Draymond Green   26  10.210526  7.013158  7.881579  2.026316
# 20542      Ivica Zubac   19   7.473684  0.789474  4.184211  0.368421
#
#         BLK/Dis    FG/Dis     3Pper    2p/Dis    FT/Dis Pos
# 0      1.138462  0.436803       NaN  0.436803  0.783251   C
# 170    0.088608  0.481768       NaN  0.481768  0.868852  SG
# 171    0.083333       NaN       NaN       NaN       NaN  SG
# 172    0.000000       NaN       NaN       NaN       NaN  SF
# 173    0.048780  0.386207       NaN  0.386207  0.750000  SF
# ...         ...       ...       ...       ...       ...  ..
# 20146  2.000000       NaN       NaN       NaN       NaN  SF
# 20147  0.961538  0.469453  0.377193  0.522843  0.618705  SF
# 20148  0.126984  0.425249  0.365672  0.473054  0.890411  PG
# 20150  1.394737  0.418462  0.307985  0.493540  0.708920  PF
# 20542  0.868421  0.529412  0.000000  0.536170  0.653061   C
#
# [20543 rows x 12 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20543 entries, 0 to 20542
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   20543 non-null  object
#  1   Age      20543 non-null  int64
#  2   PPG      20543 non-null  object
#  3   ASG      20543 non-null  object
#  4   RBG      20543 non-null  object
#  5   STL/Dis  20543 non-null  object
#  6   BLK/Dis  20543 non-null  object
#  7   FG/Dis   20543 non-null  object
#  8   3Pper    20543 non-null  object
#  9   2p/Dis   20543 non-null  object
#  10  FT/Dis   20543 non-null  object
#  11  Pos      20543 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.0+ MB

# %%
#d1 = lambda x:float(x[1:-1])

# %%
#df1.TOV= df1.TOV.apply(d1)

# %%
df1 = df1.fillna('')
df1
# Out:
#                 Player  Age        PPG       ASG       RBG   STL/Dis  \
# 0      Zaid Abdul-Aziz   28   9.676923  1.292308  7.507692  0.569231
# 170        Mike Newlin   26  14.392405  5.101266  3.291139  1.405063
# 171      Connie Norman   21
# 172     Willie Norwood   27
# 173          Jim Owens   24    3.02439  1.195122   1.04878  0.390244
# ...                ...  ...        ...       ...       ...       ...
# 20146     Jerami Grant   22
# 20147     Jerami Grant   22   5.397436  0.589744  2.551282  0.423077
# 20148     Jerian Grant   24   5.873016  1.904762  1.761905  0.746032
# 20150   Draymond Green   26  10.210526  7.013158  7.881579  2.026316
# 20542      Ivica Zubac   19   7.473684  0.789474  4.184211  0.368421
#
#         BLK/Dis    FG/Dis     3Pper    2p/Dis    FT/Dis Pos
# 0      1.138462  0.436803            0.436803  0.783251   C
# 170    0.088608  0.481768            0.481768  0.868852  SG
# 171    0.083333                                          SG
# 172         0.0                                          SF
# 173     0.04878  0.386207            0.386207      0.75  SF
# ...         ...       ...       ...       ...       ...  ..
# 20146       2.0                                          SF
# 20147  0.961538  0.469453  0.377193  0.522843  0.618705  SF
# 20148  0.126984  0.425249  0.365672  0.473054  0.890411  PG
# 20150  1.394737  0.418462  0.307985   0.49354   0.70892  PF
# 20542  0.868421  0.529412       0.0   0.53617  0.653061   C
#
# [20543 rows x 12 columns]

# %%
#x = np.random.normal(50, 3, 1000)
#source = {"Pos": ["PG"]*1000, "PTS": x}
#df1 = pd.DataFrame(source)

# Calculating mean and Stdev of PTS
#df1_mean = np.mean(df1["PTS"])
#df1_std = np.std(df1["PTS"])
 
# Calculating probability density function (PDF)
#pdf = stats.norm.pdf(df1["PTS"].sort_values(), df1_mean, df1_std)

# Drawing a graph
#plt.plot(df1["PTS"].sort_values(), pdf)
#plt.xlim([40,60])  
#plt.xlabel("PPS", size=12)    
#plt.ylabel("Frequency", size=12)                
#plt.grid(True, alpha=0.3, linestyle="--")
#plt.show()

# %%
df1.to_excel('seasons(updated).xlsx', sheet_name = 'Data')

# %%
with pd.ExcelWriter('seasons(updated).xlsx') as writer:
    df1.to_excel(writer, sheet_name = 'Data')

# %%
sns.distplot(df1['3Pper'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_11456\252697939.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['3Pper'], bins=25)
# <Axes: xlabel='3Pper', ylabel='Density'>

# %%
sns.distplot(df1['FT/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_11456\850318204.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FT/Dis'], bins=25)
# <Axes: xlabel='FT/Dis', ylabel='Density'>

# %%
sns.distplot(df1['FG/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_11456\1828129257.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FG/Dis'], bins=25)
# <Axes: xlabel='FG/Dis', ylabel='Density'>

# %%
sns.distplot(df1['2p/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_11456\12801311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['2p/Dis'], bins=25)
# <Axes: xlabel='2p/Dis', ylabel='Density'>

# %%
df1.head()
# Out:
#               Player  Age        PPG       ASG       RBG   STL/Dis   BLK/Dis  \
# 0    Zaid Abdul-Aziz   28   9.676923  1.292308  7.507692  0.569231  1.138462
# 170      Mike Newlin   26  14.392405  5.101266  3.291139  1.405063  0.088608
# 171    Connie Norman   21                                           0.083333
# 172   Willie Norwood   27                                                0.0
# 173        Jim Owens   24    3.02439  1.195122   1.04878  0.390244   0.04878
#
#        FG/Dis 3Pper    2p/Dis    FT/Dis Pos
# 0    0.436803        0.436803  0.783251   C
# 170  0.481768        0.481768  0.868852  SG
# 171                                      SG
# 172                                      SF
# 173  0.386207        0.386207      0.75  SF

# %%
sns.jointplot(x='3Pper',y='Pos',data=df1)

# %%
sns.jointplot(x='FG/Dis',y='Pos',data=df1)

# %%
sns.jointplot(x='FT/Dis',y='Pos',data=df1)

# %%
sns.jointplot(x='2p/Dis',y='Pos',data=df1)

# %%
sns.pairplot(df1, hue ='Pos')
