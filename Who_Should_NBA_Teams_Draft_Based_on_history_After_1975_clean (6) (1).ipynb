# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df1 = pd.read_excel(r"C:\Users\sbrooks003\OneDrive - defiance.edu\seasons(updated).xlsx",sheet_name='Sheet1')
df1
# Out:
#        Year                Player Pos  Age   Tm   G    GS        MPG    MP  \
# 0      1975       Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450
# 1      1975  Kareem Abdul-Jabbar*   C   27  MIL  65   NaN  42.261538  2747
# 2      1975             Don Adams  SF   27  DET  51   NaN  26.980392  1376
# 3      1975          Rick Adelman  PG   28  TOT  58   NaN  18.517241  1074
# 4      1975          Lucius Allen  PG   27  TOT  66   NaN  35.651515  2353
# ...     ...                   ...  ..  ...  ...  ..   ...        ...   ...
# 20538  2017           Cody Zeller  PF   24  CHO  62  58.0  27.822581  1725
# 20539  2017          Tyler Zeller   C   27  BOS  51   5.0  10.294118   525
# 20540  2017     Stephen Zimmerman   C   20  ORL  19   0.0   5.684211   108
# 20541  2017           Paul Zipser  SF   22  CHI  44  18.0  19.159091   843
# 20542  2017           Ivica Zubac   C   19  LAL  38  11.0  16.026316   609
#
#         PER  ...        RBG  TRB       ASG  AST  STL  BLK   TOV   PF  \
# 0      17.1  ...   7.507692  488  1.292308   84   37   74   NaN  128
# 1      26.4  ...  14.030769  912  4.061538  264   65  212   NaN  205
# 2       8.4  ...   4.784314  244  1.470588   75   69   20   NaN  179
# 3      11.1  ...   1.637931   95  1.931034  112   70    8   NaN  101
# 4      17.5  ...   4.212121  278  5.636364  372  136   29   NaN  217
# ...     ...  ...        ...  ...       ...  ...  ...  ...   ...  ...
# 20538  16.7  ...   6.532258  405  1.596774   99   62   58  65.0  189
# 20539  13.0  ...   2.431373  124  0.823529   42    7   21  20.0   61
# 20540   7.3  ...   1.842105   35  0.210526    4    2    5   3.0   17
# 20541   6.9  ...   2.840909  125  0.818182   36   15   16  40.0   78
# 20542  17.0  ...   4.184211  159  0.789474   30   14   33  30.0   66
#
#              PPG   PTS
# 0       9.676923   629
# 1      29.984615  1949
# 2       5.862745   299
# 3       5.500000   319
# 4      19.090909  1260
# ...          ...   ...
# 20538  10.306452   639
# 20539   3.490196   178
# 20540   1.210526    23
# 20541   5.454545   240
# 20542   7.473684   284
#
# [20543 rows x 37 columns]

# %%
df1_1 = df1.set_index('Year')
df1_1
# Out:
#                     Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# Year
# 1975       Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 1975  Kareem Abdul-Jabbar*   C   27  MIL  65   NaN  42.261538  2747  26.4
# 1975             Don Adams  SF   27  DET  51   NaN  26.980392  1376   8.4
# 1975          Rick Adelman  PG   28  TOT  58   NaN  18.517241  1074  11.1
# 1975          Lucius Allen  PG   27  TOT  66   NaN  35.651515  2353  17.5
# ...                    ...  ..  ...  ...  ..   ...        ...   ...   ...
# 2017           Cody Zeller  PF   24  CHO  62  58.0  27.822581  1725  16.7
# 2017          Tyler Zeller   C   27  BOS  51   5.0  10.294118   525  13.0
# 2017     Stephen Zimmerman   C   20  ORL  19   0.0   5.684211   108   7.3
# 2017           Paul Zipser  SF   22  CHI  44  18.0  19.159091   843   6.9
# 2017           Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#         TS%  ...        RBG  TRB       ASG  AST  STL  BLK   TOV   PF  \
# Year         ...
# 1975  0.501  ...   7.507692  488  1.292308   84   37   74   NaN  128
# 1975  0.550  ...  14.030769  912  4.061538  264   65  212   NaN  205
# 1975  0.428  ...   4.784314  244  1.470588   75   69   20   NaN  179
# 1975  0.474  ...   1.637931   95  1.931034  112   70    8   NaN  101
# 1975  0.483  ...   4.212121  278  5.636364  372  136   29   NaN  217
# ...     ...  ...        ...  ...       ...  ...  ...  ...   ...  ...
# 2017  0.604  ...   6.532258  405  1.596774   99   62   58  65.0  189
# 2017  0.508  ...   2.431373  124  0.823529   42    7   21  20.0   61
# 2017  0.346  ...   1.842105   35  0.210526    4    2    5   3.0   17
# 2017  0.503  ...   2.840909  125  0.818182   36   15   16  40.0   78
# 2017  0.547  ...   4.184211  159  0.789474   30   14   33  30.0   66
#
#             PPG   PTS
# Year
# 1975   9.676923   629
# 1975  29.984615  1949
# 1975   5.862745   299
# 1975   5.500000   319
# 1975  19.090909  1260
# ...         ...   ...
# 2017  10.306452   639
# 2017   3.490196   178
# 2017   1.210526    23
# 2017   5.454545   240
# 2017   7.473684   284
#
# [20543 rows x 36 columns]

# %%
df1 = df1.sort_values(by = 'Year', ascending = True).head(25000)
df1
# Out:
#        Year           Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975  Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 170    1975      Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975    Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 172    1975   Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975        Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# ...     ...              ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20146  2017     Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017     Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20148  2017     Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
# 20150  2017   Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
# 20542  2017      Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...       RBG  TRB       ASG  AST  STL  BLK    TOV   PF        PPG  \
# 0      ...  7.507692  488  1.292308   84   37   74    NaN  128   9.676923
# 170    ...  3.291139  260  5.101266  403  111    7    NaN  288  14.392405
# 171    ...  1.000000   12  0.333333    4    3    1    NaN    9   4.000000
# 172    ...  3.666667   88  0.666667   16   23    0    NaN   51   6.625000
# 173    ...  1.048780   43  1.195122   49   16    2    NaN   27   3.024390
# ...    ...       ...  ...       ...  ...  ...  ...    ...  ...        ...
# 20146  ...  3.500000    7  0.000000    0    0    4    3.0    5   8.000000
# 20147  ...  2.551282  199  0.589744   46   33   75   41.0  144   5.397436
# 20148  ...  1.761905  111  1.904762  120   47    8   44.0   93   5.873016
# 20150  ...  7.881579  599  7.013158  533  154  106  184.0  217  10.210526
# 20542  ...  4.184211  159  0.789474   30   14   33   30.0   66   7.473684
#
#         PTS
# 0       629
# 170    1137
# 171      48
# 172     159
# 173     124
# ...     ...
# 20146    16
# 20147   421
# 20148   370
# 20150   776
# 20542   284
#
# [20543 rows x 37 columns]

# %%
df1 = df1[df1['Year'] >= 1975]
df1
# Out:
#        Year           Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975  Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 170    1975      Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975    Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 172    1975   Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975        Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# ...     ...              ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20146  2017     Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017     Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20148  2017     Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
# 20150  2017   Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
# 20542  2017      Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...       RBG  TRB       ASG  AST  STL  BLK    TOV   PF        PPG  \
# 0      ...  7.507692  488  1.292308   84   37   74    NaN  128   9.676923
# 170    ...  3.291139  260  5.101266  403  111    7    NaN  288  14.392405
# 171    ...  1.000000   12  0.333333    4    3    1    NaN    9   4.000000
# 172    ...  3.666667   88  0.666667   16   23    0    NaN   51   6.625000
# 173    ...  1.048780   43  1.195122   49   16    2    NaN   27   3.024390
# ...    ...       ...  ...       ...  ...  ...  ...    ...  ...        ...
# 20146  ...  3.500000    7  0.000000    0    0    4    3.0    5   8.000000
# 20147  ...  2.551282  199  0.589744   46   33   75   41.0  144   5.397436
# 20148  ...  1.761905  111  1.904762  120   47    8   44.0   93   5.873016
# 20150  ...  7.881579  599  7.013158  533  154  106  184.0  217  10.210526
# 20542  ...  4.184211  159  0.789474   30   14   33   30.0   66   7.473684
#
#         PTS
# 0       629
# 170    1137
# 171      48
# 172     159
# 173     124
# ...     ...
# 20146    16
# 20147   421
# 20148   370
# 20150   776
# 20542   284
#
# [20543 rows x 37 columns]

# %%
guards = ['PG','SG']

df1[df1['Pos'].isin(guards)]
# Out:
#        Year          Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 170    1975     Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709  15.1
# 171    1975   Connie Norman  SG   21  PHI  12   NaN   6.000000    72  19.4
# 176    1975    Geoff Petrie  PG   26  POR  80   NaN  38.862500  3109  14.1
# 180    1975    Kevin Porter  PG   24  WSB  81   NaN  31.962963  2589  16.0
# 181    1975       Jim Price  PG   25  TOT  50   NaN  37.400000  1870  16.1
# ...     ...             ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20139  2017  Archie Goodwin  SG   22  NOP   3   0.0  10.000000    30  19.7
# 20140  2017  Archie Goodwin  SG   22  BRK  12   0.0  15.333333   184  18.6
# 20142  2017     Eric Gordon  SG   28  HOU  75  15.0  30.973333  2323  13.1
# 20144  2017  Treveon Graham  SG   23  CHO  27   1.0   7.000000   189  10.6
# 20148  2017    Jerian Grant  PG   24  CHI  63  28.0  16.317460  1028  13.1
#
#        ...       RBG  TRB       ASG  AST  STL  BLK    TOV   PF        PPG  \
# 170    ...  3.291139  260  5.101266  403  111    7    NaN  288  14.392405
# 171    ...  1.000000   12  0.333333    4    3    1    NaN    9   4.000000
# 176    ...  2.612500  209  5.300000  424   81   13    NaN  215  18.312500
# 180    ...  1.876543  152  8.024691  650  152   11    NaN  320  11.641975
# 181    ...  3.960000  198  5.720000  286  111   24    NaN  182  16.060000
# ...    ...       ...  ...       ...  ...  ...  ...    ...  ...        ...
# 20139  ...  0.000000    0  0.333333    1    0    1    0.0    1   5.000000
# 20140  ...  2.333333   28  1.916667   23    4    4   14.0    7   7.916667
# 20142  ...  2.680000  201  2.506667  188   48   40  121.0  150  16.226667
# 20144  ...  0.814815   22  0.222222    6    6    1    3.0   18   2.111111
# 20148  ...  1.761905  111  1.904762  120   47    8   44.0   93   5.873016
#
#         PTS
# 170    1137
# 171      48
# 176    1465
# 180     943
# 181     803
# ...     ...
# 20139    15
# 20140    95
# 20142  1217
# 20144    57
# 20148   370
#
# [8077 rows x 37 columns]

# %%
forwards = ['SF', 'PF']

df1[df1['Pos'].isin(forwards)]
# Out:
#        Year          Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 172    1975  Willie Norwood  SF   27  DET  24   NaN  14.458333   347  17.3
# 173    1975       Jim Owens  SF   24  PHO  41   NaN  10.536585   432   9.3
# 175    1975    Curtis Perry  PF   26  PHO  79   NaN  34.025316  2688  17.1
# 177    1975   Howard Porter  SF   26  TOT  58   NaN  20.051724  1163  13.4
# 178    1975   Howard Porter  SF   26  NYK  17   NaN   7.823529   133   8.4
# ...     ...             ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20141  2017    Aaron Gordon  SF   21  ORL  80  72.0  28.725000  2298  14.4
# 20145  2017    Jerami Grant  SF   22  TOT  80   4.0  19.137500  1531  10.1
# 20146  2017    Jerami Grant  SF   22  PHI   2   0.0  20.500000    41   3.3
# 20147  2017    Jerami Grant  SF   22  OKC  78   4.0  19.102564  1490  10.3
# 20150  2017  Draymond Green  PF   26  GSW  76  76.0  32.513158  2471  16.5
#
#        ...        RBG  TRB       ASG  AST  STL  BLK    TOV   PF        PPG  \
# 172    ...   3.666667   88  0.666667   16   23    0    NaN   51   6.625000
# 173    ...   1.048780   43  1.195122   49   16    2    NaN   27   3.024390
# 175    ...  11.898734  940  2.354430  186  108   78    NaN  288  13.392405
# 177    ...   4.379310  254  0.327586   19   23   26    NaN   93   8.068966
# 178    ...   2.235294   38  0.117647    2    3    1    NaN   17   1.941176
# ...    ...        ...  ...       ...  ...  ...  ...    ...  ...        ...
# 20141  ...   5.062500  405  1.875000  150   64   40   89.0  172  12.737500
# 20145  ...   2.575000  206  0.575000   46   33   79   44.0  149   5.462500
# 20146  ...   3.500000    7  0.000000    0    0    4    3.0    5   8.000000
# 20147  ...   2.551282  199  0.589744   46   33   75   41.0  144   5.397436
# 20150  ...   7.881579  599  7.013158  533  154  106  184.0  217  10.210526
#
#         PTS
# 172     159
# 173     124
# 175    1058
# 177     468
# 178      33
# ...     ...
# 20141  1019
# 20145   437
# 20146    16
# 20147   421
# 20150   776
#
# [8191 rows x 37 columns]

# %%
center = ['C']

df1[df1['Pos'].isin(center)]
# Out:
#        Year            Player Pos  Age   Tm   G    GS        MPG    MP   PER  \
# 0      1975   Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450  17.1
# 174    1975   Steve Patterson   C   26  CLE  81   NaN  15.666667  1269  11.3
# 185    1975      Clifford Ray   C   26  GSW  82   NaN  30.719512  2519  15.0
# 187    1975         Tom Riker   C   24  NYK  51   NaN   9.470588   483   9.4
# 191    1975     Rick Roberson   C   27  NOJ  16   NaN  21.187500   339  13.1
# ...     ...               ...  ..  ...  ...  ..   ...        ...   ...   ...
# 20161  2017  Montrezl Harrell   C   23  HOU  58  14.0  18.344828  1064  19.2
# 20169  2017     Udonis Haslem   C   36  MIA  17   0.0   7.647059   130   8.4
# 20137  2017       Rudy Gobert   C   24  UTA  81  81.0  33.876543  2744  23.3
# 20143  2017     Marcin Gortat   C   32  WAS  82  82.0  31.170732  2556  15.5
# 20542  2017       Ivica Zubac   C   19  LAL  38  11.0  16.026316   609  17.0
#
#        ...        RBG   TRB       ASG  AST  STL  BLK    TOV   PF        PPG  \
# 0      ...   7.507692   488  1.292308   84   37   74    NaN  128   9.676923
# 174    ...   4.061728   329  1.148148   93   21   20    NaN  128   4.567901
# 185    ...  10.609756   870  2.170732  178   95  116    NaN  305   9.378049
# 187    ...   2.098039   107  0.372549   19   15    5    NaN   64   2.980392
# 191    ...   7.375000   118  1.437500   23    7    8    NaN   49   7.437500
# ...    ...        ...   ...       ...  ...  ...  ...    ...  ...        ...
# 20161  ...   3.775862   219  1.103448   64   20   42   44.0  126   9.086207
# 20169  ...   2.117647    36  0.352941    6    5    1    8.0   22   1.823529
# 20137  ...  12.777778  1035  1.197531   97   49  214  148.0  246  14.037037
# 20143  ...  10.353659   849  1.475610  121   40   65  118.0  213  10.768293
# 20542  ...   4.184211   159  0.789474   30   14   33   30.0   66   7.473684
#
#         PTS
# 0       629
# 174     370
# 185     769
# 187     152
# 191     119
# ...     ...
# 20161   527
# 20169    31
# 20137  1137
# 20143   883
# 20542   284
#
# [4068 rows x 37 columns]

# %%
df1 = df1.filter(items = ['Player','Age','PTS', 'ASG', 'TRB','STL','BLK','TOV','FG%','3P%','FT%','PER','Pos',])
df1
# Out:
#                 Player  Age   PTS       ASG  TRB  STL  BLK    TOV    FG%  \
# 0      Zaid Abdul-Aziz   28   629  1.292308  488   37   74    NaN  0.437
# 170        Mike Newlin   26  1137  5.101266  260  111    7    NaN  0.482
# 171      Connie Norman   21    48  0.333333   12    3    1    NaN  0.523
# 172     Willie Norwood   27   159  0.666667   88   23    0    NaN  0.520
# 173          Jim Owens   24   124  1.195122   43   16    2    NaN  0.386
# ...                ...  ...   ...       ...  ...  ...  ...    ...    ...
# 20146     Jerami Grant   22    16  0.000000    7    0    4    3.0  0.353
# 20147     Jerami Grant   22   421  0.589744  199   33   75   41.0  0.469
# 20148     Jerian Grant   24   370  1.904762  111   47    8   44.0  0.425
# 20150   Draymond Green   26   776  7.013158  599  154  106  184.0  0.418
# 20542      Ivica Zubac   19   284  0.789474  159   14   33   30.0  0.529
#
#          3P%    FT%   PER Pos
# 0        NaN  0.783  17.1   C
# 170      NaN  0.869  15.1  SG
# 171      NaN  0.667  19.4  SG
# 172      NaN  0.738  17.3  SF
# 173      NaN  0.750   9.3  SF
# ...      ...    ...   ...  ..
# 20146  0.000  0.500   3.3  SF
# 20147  0.377  0.619  10.3  SF
# 20148  0.366  0.890  13.1  PG
# 20150  0.308  0.709  16.5  PF
# 20542  0.000  0.653  17.0   C
#
# [20543 rows x 13 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20543 entries, 0 to 20542
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  20543 non-null  object
#  1   Age     20543 non-null  int64
#  2   PTS     20543 non-null  int64
#  3   ASG     20543 non-null  float64
#  4   TRB     20543 non-null  int64
#  5   STL     20543 non-null  int64
#  6   BLK     20543 non-null  int64
#  7   TOV     19645 non-null  float64
#  8   FG%     20450 non-null  float64
#  9   3P%     15416 non-null  float64
#  10  FT%     19758 non-null  float64
#  11  PER     20538 non-null  float64
#  12  Pos     20543 non-null  object
# dtypes: float64(6), int64(5), object(2)
# memory usage: 2.2+ MB

# %%
#d1 = lambda x:float(x[1:-1])

# %%
#df1.TOV= df1.TOV.apply(d1)

# %%
df1 = df1.fillna('')
df1
# Out:
#                 Player  Age   PTS  AST  TRB  STL  BLK    TOV    FG%    3P%  \
# 0      Zaid Abdul-Aziz   28   629   84  488   37   74         0.437
# 170        Mike Newlin   26  1137  403  260  111    7         0.482
# 171      Connie Norman   21    48    4   12    3    1         0.523
# 172     Willie Norwood   27   159   16   88   23    0          0.52
# 173          Jim Owens   24   124   49   43   16    2         0.386
# ...                ...  ...   ...  ...  ...  ...  ...    ...    ...    ...
# 20146     Jerami Grant   22    16    0    7    0    4    3.0  0.353    0.0
# 20147     Jerami Grant   22   421   46  199   33   75   41.0  0.469  0.377
# 20148     Jerian Grant   24   370  120  111   47    8   44.0  0.425  0.366
# 20150   Draymond Green   26   776  533  599  154  106  184.0  0.418  0.308
# 20542      Ivica Zubac   19   284   30  159   14   33   30.0  0.529    0.0
#
#          FT%   PER Pos
# 0      0.783  17.1   C
# 170    0.869  15.1  SG
# 171    0.667  19.4  SG
# 172    0.738  17.3  SF
# 173     0.75   9.3  SF
# ...      ...   ...  ..
# 20146    0.5   3.3  SF
# 20147  0.619  10.3  SF
# 20148   0.89  13.1  PG
# 20150  0.709  16.5  PF
# 20542  0.653  17.0   C
#
# [20543 rows x 13 columns]

# %%
#x = np.random.normal(50, 3, 1000)
#source = {"Pos": ["PG"]*1000, "PTS": x}
#df1 = pd.DataFrame(source)

# Calculating mean and Stdev of PTS
#df1_mean = np.mean(df1["PTS"])
#df1_std = np.std(df1["PTS"])
 
# Calculating probability density function (PDF)
#pdf = stats.norm.pdf(df1["PTS"].sort_values(), df1_mean, df1_std)

# Drawing a graph
#plt.plot(df1["PTS"].sort_values(), pdf)
#plt.xlim([40,60])  
#plt.xlabel("PPS", size=12)    
#plt.ylabel("Frequency", size=12)                
#plt.grid(True, alpha=0.3, linestyle="--")
#plt.show()

# %%
df1.to_excel('seasons(updated).xlsx', sheet_name = 'Data')

# %%
with pd.ExcelWriter('seasons(updated).xlsx') as writer:
    df1.to_excel(writer, sheet_name = 'Data')

# %%
sns.distplot(df1['3P%'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_13492\4271090780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['3P%'], bins=25)
# <Axes: xlabel='3P%', ylabel='Density'>

# %%
sns.distplot(df1['FT%'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_13492\4152268900.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FT%'], bins=25)
# <Axes: xlabel='FT%', ylabel='Density'>

# %%
sns.distplot(df1['FG%'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_13492\1479800393.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FG%'], bins=25)
# <Axes: xlabel='FG%', ylabel='Density'>

# %%
df1.head()

# %%
sns.jointplot(x='3P%',y='Pos',data=df1)

# %%
sns.jointplot(x='FG%',y='Pos',data=df1)

# %%
sns.jointplot(x='FT%',y='Pos',data=df1)

# %%
sns.pairplot(df1, hue ='Pos')
